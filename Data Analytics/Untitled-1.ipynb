# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np
import seaborn as sns
import matplotlib as mlt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
data = pd.read_csv('courses.csv')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)
data.drop("Side", axis=1, inplace=True)
data.drop("State", axis=1, inplace=True)
data.drop("State_Number", axis=1, inplace=True)
data.drop("Timezone", axis=1, inplace=True)
data.drop("Humidity(%)", axis=1, inplace=True)
data.drop("Distance(mi)", axis=1, inplace=True)
data.drop('Temperature(F)',axis=1,inplace=True)

# %%
# Import `StandardScaler` from `sklearn.preprocessing`
from sklearn.preprocessing import MinMaxScaler

# define min max scaler
scaler = MinMaxScaler()

# transform data
scaled = scaler.fit_transform(data)

data = pd.DataFrame(scaled,columns=['Severity','Visibility(mi)','Weather_Condition','Day_Night'])
data
# Out:
#       Severity  Visibility(mi)  Weather_Condition  Day_Night
# 0          0.0             1.0           1.000000        1.0
# 1          0.0             1.0           1.000000        1.0
# 2          0.0             1.0           1.000000        0.0
# 3          0.0             1.0           0.666667        1.0
# 4          0.5             1.0           1.000000        1.0
# ...        ...             ...                ...        ...
# 7923       0.0             1.0           0.666667        1.0
# 7924       0.0             1.0           0.666667        1.0
# 7925       0.0             1.0           0.666667        1.0
# 7926       0.0             1.0           0.666667        1.0
# 7927       0.0             1.0           0.666667        1.0
#
# [7928 rows x 4 columns]

# %%
# Import `train_test_split` from `sklearn.model_selection`
from sklearn.model_selection import train_test_split

# Specify the data 
X = data[['Visibility(mi)','Weather_Condition','Day_Night']]


# Specify the target labels and flatten the array 
y= data['Severity']
y = np.array(y)

# Split the data up in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# MODEL 1
model = Sequential([
     Dense(9, activation='relu', input_shape=(3,)),
     Dense(81,activation='relu'),
     Dense(1),
     ])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['MSE'])
                   
model.fit(X_train, y_train,epochs=10, batch_size=100, verbose=1)

y_pred4 = model.predict(X_test)

score = model.evaluate(X_test, y_test,verbose=1)

print(score)
# Out:
# Epoch 1/10
# 64/64 [==============================] - 2s 4ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 2/10
# 64/64 [==============================] - 0s 5ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 3/10
# 64/64 [==============================] - 0s 5ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 4/10
# 64/64 [==============================] - 0s 5ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 5/10
# 64/64 [==============================] - 0s 4ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 6/10
# 64/64 [==============================] - 0s 5ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 7/10
# 64/64 [==============================] - 0s 5ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 8/10
# 64/64 [==============================] - 0s 5ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 9/10
# 64/64 [==============================] - 0s 7ms/step - loss: 9.8307e-09 - MSE: 0.2867
# Epoch 10/10
# 64/64 [==============================] - 0s 7ms/step - loss: 9.8307e-09 - MSE: 0.2867
# 50/50 [==============================] - 0s 3ms/step
# 50/50 [==============================] - 1s 5ms/step - loss: 1.0974e-08 - MSE: 0.2979
# [1.0973869812858084e-08, 0.297931045293808]

# %%
# MODEL 2
model = Sequential([
     Dense(6, activation='relu', input_shape=(3,)),
     Dense(12,activation='relu'),
     Dense(24,activation='relu'),
     Dense(1),
     ])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['MSE'])
                   
model.fit(X_train, y_train,epochs=10, batch_size=100, verbose=1)

y_pred5 = model.predict(X_test)

score = model.evaluate(X_test, y_test,verbose=1)

print(score)
# Out:
# Epoch 1/10
# 64/64 [==============================] - 2s 6ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 2/10
# 64/64 [==============================] - 0s 7ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 3/10
# 64/64 [==============================] - 1s 8ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 4/10
# 64/64 [==============================] - 0s 6ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 5/10
# 64/64 [==============================] - 0s 6ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 6/10
# 64/64 [==============================] - 0s 7ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 7/10
# 64/64 [==============================] - 0s 6ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 8/10
# 64/64 [==============================] - 0s 5ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 9/10
# 64/64 [==============================] - 0s 7ms/step - loss: 9.8307e-09 - MSE: 0.0696
# Epoch 10/10
# 64/64 [==============================] - 0s 6ms/step - loss: 9.8307e-09 - MSE: 0.0696
# 50/50 [==============================] - 0s 4ms/step
# 50/50 [==============================] - 1s 7ms/step - loss: 1.0974e-08 - MSE: 0.0770
# [1.0973869812858084e-08, 0.07699044793844223]
